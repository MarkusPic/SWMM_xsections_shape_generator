# %% [raw]
# .. _examples_for_standard_profiles:

# %% [markdown]
# # Standard cross section

# %%
from shape_generator import CrossSectionHolding as CrossSection

# %%
unit = 'cm'
height = 200
width = 100
label = 'test'

# %% [markdown]
# r_channel (float)
#
# r_roof (float)
#
# r_wall (float)
#
# slope_bench (float)
#
# r_round (float)
#
# r_wall_bottom (float)
#
# h_bench (float)
#
# pre_bench (float)
#
# w_channel (float)

# %% [raw]
# Dictionary
# """"""""""
#
# +---------+---------------------+--------------------------+
# | english | deutsch             | description              |
# +=========+=====================+==========================+
# | channel | Trockenwetter-Rinne |                          |
# +---------+---------------------+--------------------------+
# | roof    | Firste/Decke        | Bogen an der Rohr Firste |
# +---------+---------------------+--------------------------+
# | wall    | Wand                | Radius der Seitenwand    |
# +---------+---------------------+--------------------------+
# | bench   | Berme               | Neigung um der TW-Rinne  |
# +---------+---------------------+--------------------------+

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit)

# %%
import pandas as pd
pd.DataFrame(cs.get_points()).T.rename(columns={0:'$h_i$', 1:'$A_i$'})
# Out:
#    $h_i$  $A_i$
# 0    0.0    0.0
# 1    0.0   50.0
# 2  200.0   50.0
# 3  200.0    0.0

# %%
fig = cs.profile_figure()

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           r_channel=35)
fig = cs.profile_figure()
# Out:
# /home/markus/PycharmProjects/SWMM_xsections_shape_generator/shape_generator/helpers.py:211: UserWarning: unused part of the shape detected. Ignoring this part.
#   warnings.warn('unused part of the shape detected. Ignoring this part.')

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           r_channel=35, 
                           pre_bench=45)
fig = cs.profile_figure()

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           r_channel=35, 
                           pre_bench=45, 
                           slope_bench=5)
fig = cs.profile_figure()

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           r_channel=35, 
                           h_bench=25, 
                           slope_bench=5)
fig = cs.profile_figure()

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           r_channel=35, 
                           w_channel=25, 
                           slope_bench=5)
fig = cs.profile_figure()

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           slope_bench=15)
fig = cs.profile_figure()

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           r_channel=30, 
                           slope_bench=15)
fig = cs.profile_figure()
# Out:
# /home/markus/PycharmProjects/SWMM_xsections_shape_generator/shape_generator/helpers.py:211: UserWarning: unused part of the shape detected. Ignoring this part.
#   warnings.warn('unused part of the shape detected. Ignoring this part.')

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           r_roof=100)
fig = cs.profile_figure()

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           r_roof=30, r_wall=110)
fig = cs.profile_figure()

# %%
cs = CrossSection.standard(label, None, height=height, width=width, unit=unit, 
                           r_roof=20)
fig = cs.profile_figure()

# %% [markdown]
# You can even make a standard egg cross section

# %%
r = 30.
cs = CrossSection.standard(label, None, height=r * 3, width=r * 2, unit=unit, 
                           r_channel=r / 2, r_wall=3 * r,  r_wall_bottom=3 * r, r_roof=r, h_bench=r/5)
fig = cs.profile_figure()
# Out:
# /home/markus/PycharmProjects/SWMM_xsections_shape_generator/shape_generator/helpers.py:211: UserWarning: unused part of the shape detected. Ignoring this part.
#   warnings.warn('unused part of the shape detected. Ignoring this part.')

# %% [markdown]
# The warning occurred because the r_wall part was ignored. However, this input cannot be omitted, otherwise the following will happen.

# %%
r = 30.
cs = CrossSection.standard(label, None, height=r * 3, width=r * 2, unit=unit, 
                           r_channel=r / 2, 
                           r_wall=3 * r,  
                           r_roof=r, 
                           h_bench=r/5)
fig = cs.profile_figure()
# Out:
# /home/markus/PycharmProjects/SWMM_xsections_shape_generator/shape_generator/helpers.py:211: UserWarning: unused part of the shape detected. Ignoring this part.
#   warnings.warn('unused part of the shape detected. Ignoring this part.')

# %%
r = 30.
cs = CrossSection.standard(label, None, height=r * 3, width=r * 2, unit=unit, 
                           r_channel=r / 2, 
                           r_wall_bottom=3 * r,  
                           r_roof=r, 
                           h_bench=r/5)
fig = cs.profile_figure()
