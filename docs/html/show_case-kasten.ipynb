# %% [raw]
# .. _examples_for_box_shaped_profiles:

# %% [markdown]
# # Examples for box shaped profiles

# %%
from shape_generator import CrossSectionHolding as CrossSection
unit = 'cm'  # only for the title in the plot

# %%
no = 'K.60'
height = 200
width = 150
kasten = CrossSection.box_from_string(no, height=height, width=width, unit=unit)

fig = kasten.profile_figure()

# %%
no = 'K.R_B'
height = 200
width = 150
kasten = CrossSection.box_from_string(no, height=height, width=width, unit=unit)

fig = kasten.profile_figure()

# %%
no = 'K.60H_K'
height = 200
width = 100
kasten = CrossSection.box_from_string(no, height=height, width=width, unit=unit)

fig = kasten.profile_figure()

# %%
from shape_generator.converter_swmm_api import convert_shape_generator_to_curve
print(convert_shape_generator_to_curve(kasten).to_inp_line())
# Out:
# Pr_K.60H_K  SHAPE  0.0020  0.0488
# Pr_K.60H_K         0.0080  0.0967
# Pr_K.60H_K         0.0170  0.1387
# Pr_K.60H_K         0.0300  0.1800
# Pr_K.60H_K         0.0430  0.2102
# Pr_K.60H_K         0.1879  0.5000
# Pr_K.60H_K         0.7540  0.4999
# Pr_K.60H_K         0.7890  0.4939
# Pr_K.60H_K         0.8240  0.4776
# Pr_K.60H_K         0.8610  0.4480
# Pr_K.60H_K         0.8950  0.4073
# Pr_K.60H_K         0.9250  0.3571
# Pr_K.60H_K         0.9510  0.2973
# Pr_K.60H_K         0.9720  0.2299
# Pr_K.60H_K         0.9870  0.1591
# Pr_K.60H_K         0.9970  0.0772
