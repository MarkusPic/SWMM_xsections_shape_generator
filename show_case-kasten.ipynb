# %%
from shape_generator.profile_gen import box_profile_from_string

# %%
no = 'K.60'
height = 2000
width = 1500
kasten = box_profile_from_string(no, height=height, width=width)

fig = kasten.profile_abs_figure()
# Out:
# ______________________________
# Pr_K.60  ->  K.600

# %%
no = 'K.R_B'
height = 2000
width = 1500
kasten = box_profile_from_string(no, height=height, width=width)

fig = kasten.profile_abs_figure()
# Out:
# ______________________________
# Pr_K.R_B  ->  K.R_B

# %%
no = 'K.60H_K'
height = 2000
width = 1000
kasten = box_profile_from_string(no, height=height, width=width)

fig = kasten.profile_abs_figure()
# Out:
# ______________________________
# Pr_K.60H_K  ->  K.600H_K

# %%
print(kasten.inp_string())
# Out:
# Pr_K.60H_K_2000x1000  shape 0.0031 0.0305
# Pr_K.60H_K_2000x1000        0.0063 0.0429
# Pr_K.60H_K_2000x1000        0.0094 0.0523
# Pr_K.60H_K_2000x1000        0.0126 0.0601
# Pr_K.60H_K_2000x1000        0.0157 0.0668
# Pr_K.60H_K_2000x1000        0.0188 0.0728
# Pr_K.60H_K_2000x1000        0.0220 0.0782
# Pr_K.60H_K_2000x1000        0.0251 0.0831
# Pr_K.60H_K_2000x1000        0.0282 0.0876
# Pr_K.60H_K_2000x1000        0.0314 0.0918
# Pr_K.60H_K_2000x1000        0.0345 0.0957
# Pr_K.60H_K_2000x1000        0.0377 0.0994
# Pr_K.60H_K_2000x1000        0.0408 0.1028
# Pr_K.60H_K_2000x1000        0.0439 0.1061
# Pr_K.60H_K_2000x1000        0.1879 0.2500
# Pr_K.60H_K_2000x1000        0.7500 0.2500
# Pr_K.60H_K_2000x1000        0.7532 0.2500
# Pr_K.60H_K_2000x1000        0.7563 0.2499
# Pr_K.60H_K_2000x1000        0.7595 0.2498
# Pr_K.60H_K_2000x1000        0.7627 0.2497
# Pr_K.60H_K_2000x1000        0.7658 0.2495
# Pr_K.60H_K_2000x1000        0.7690 0.2493
# ...
